# %% [markdown]
# **Categorical to Numerical**
#
# - It is very important to convert categorical data to Numerical data
#
# - Because in Machine learning models the input is in the form numbers
#
# - ML models developed by maths,so passing text data is not works
#
# - We have different types of methods are there
#
#     - map method
#
#     - np.where
#
#     - One hot encoder
#
#     - Label Encoder

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\hp\OneDrive\Documents\FSDS 7\EDA_PYTHON\Visadataset.csv")
df.head(2)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %% [markdown]
# **Map method**
#
# - First get the unique labels for each column
#
# - create a dictonary by providing values to each label
#
# - For example case status has two labels,we are providing two values
#
#   - Assign 0 for certified
#
#   - Assign 1 for denied

# %%
df['case_status'].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
d={'Denied':1,'Certified':0}
d
# Out:
# {'Denied': 1, 'Certified': 0}

# %%
df['case_status'].map(d)
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 25475    0
# 25476    0
# 25477    0
# 25478    0
# 25479    0
# Name: case_status, Length: 25480, dtype: int64

# %%
df['case_status_new']=df['case_status'].map(d)

# %%
df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
df=pd.read_csv(r"C:\Users\hp\OneDrive\Documents\FSDS 7\EDA_PYTHON\Visadataset.csv")
d={'Denied':1,'Certified':0}
df['case_status_new']=df['case_status'].map(d)
df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
df['has_job_experience'].unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
d1={'N':0,'Y':1}
d1
# Out:
# {'N': 0, 'Y': 1}

# %%
df['has_job_experience'].map(d1)
# Out:
# 0        0
# 1        1
# 2        0
# 3        0
# 4        1
#         ..
# 25475    1
# 25476    1
# 25477    1
# 25478    1
# 25479    1
# Name: has_job_experience, Length: 25480, dtype: int64

# %%
df['has_job_experience_new']=df['has_job_experience'].map(d1)
df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
df=pd.read_csv(r"C:\Users\hp\OneDrive\Documents\FSDS 7\EDA_PYTHON\Visadataset.csv")
d1={'N':0,'Y':1}
df['has_job_experience_new']=df['has_job_experience'].map(d1)
df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
labels=(df['case_status'].unique())
values=[i for i in range(len(labels))] 
values
# Out:
# [0, 1]

# %%
cols=df.select_dtypes(include='object').columns
for i in cols:
    labels=(df[i].unique())
    values=[i for i in range(len(labels))]
    d=dict(zip(labels,values))
    df[i]=df[i].map(d)
    
df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          0                      0                   0
# 1            1          0                      1                   1
# 2            2          0                      2                   0
# 3            3          0                      2                   0
# 4            4          1                      1                   1
# ...        ...        ...                    ...                 ...
# 25475    25475          0                      2                   1
# 25476    25476          0                      0                   1
# 25477    25477          0                      1                   1
# 25478    25478          0                      1                   1
# 25479    25479          0                      2                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %% [markdown]
# **label encoder**
#
# - Label encoder is a package under **sickit learn**
#
# - Sickit-learn is heart of Machine Learning
#
# - In side we have a method called **Preproceesing**
#
# - Under Preprocessing we have **labelencoder**
#
# - scikit-learn we will write as **sklearn**
#
# - Any sklearn package we have 3 steps
#
#    - Step1-1: Read the package
#
#    - Step-2: Save the package
#
#    - Step-3: Apply Fit transform

# %%
df=pd.read_csv(r"C:\Users\hp\OneDrive\Documents\FSDS 7\EDA_PYTHON\Visadataset.csv")

# %%
# Step1-1: Read the package
from sklearn.preprocessing import LabelEncoder

#Step-2: Save the package
le=LabelEncoder()

# Apply Fit transform
df['case_status']=le.fit_transform(df['case_status'])

# %%
df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
df=pd.read_csv(r"C:\Users\hp\OneDrive\Documents\FSDS 7\EDA_PYTHON\Visadataset.csv")

# Step1-1: Read the package
from sklearn.preprocessing import LabelEncoder

#Step-2: Save the package
le=LabelEncoder()

# Apply Fit transform
df['continent']=le.fit_transform(df['continent'])

# %%
df
# Out:
#          case_id  continent education_of_employee has_job_experience  \
# 0         EZYV01          1           High School                  N
# 1         EZYV02          1              Master's                  Y
# 2         EZYV03          1            Bachelor's                  N
# 3         EZYV04          1            Bachelor's                  N
# 4         EZYV05          0              Master's                  Y
# ...          ...        ...                   ...                ...
# 25475  EZYV25476          1            Bachelor's                  Y
# 25476  EZYV25477          1           High School                  Y
# 25477  EZYV25478          1              Master's                  Y
# 25478  EZYV25479          1              Master's                  Y
# 25479  EZYV25480          1            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cols=df.select_dtypes(include='object').columns
for i in cols:
    le=LabelEncoder()
    df[i]=le.fit_transform(df[i])
    
df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          1                      2                   0
# 1            1          1                      3                   1
# 2            2          1                      0                   0
# 3            3          1                      0                   0
# 4            4          0                      3                   1
# ...        ...        ...                    ...                 ...
# 25475    17204          1                      0                   1
# 25476    17205          1                      2                   1
# 25477    17206          1                      3                   1
# 25478    17207          1                      3                   1
# 25479    17209          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %%
le1=le.inverse_transform(df['case_status'].unique())
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %% [markdown]
# **inverse transform**
#
# - in order to see inverse of labels we need to perform individually again

# %%
df=pd.read_csv(r"C:\Users\hp\OneDrive\Documents\FSDS 7\EDA_PYTHON\Visadataset.csv")


from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()


df['case_status']=le.fit_transform(df['case_status'])
print(df['case_status'].values)
print(le.inverse_transform(df['case_status']))
# Out:
# [1 0 1 ... 0 0 0]
# ['Denied' 'Certified' 'Denied' ... 'Certified' 'Certified' 'Certified']

# %% [markdown]
# **LabelEncoder will use most of the time**

# %% [markdown]
# **np.where**
#
# - np.where applicable only for binary
#
# - np.where will take 3 arguments
#
#   - condition
#
#   - True value
#
#   - False value

# %% [markdown]
# $scenario$
#
# - For example case status value equal to Cerified replace with zero
#
# - otherwise replace with 1

# %%
df=pd.read_csv(r"C:\Users\hp\OneDrive\Documents\FSDS 7\EDA_PYTHON\Visadataset.csv")
col1=df['case_status']=='Certified'
df['case_status']=np.where(col1,1,0)
df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **One hot encoder**
#
# - One hot means if onne is ON another one is OFF
#
# - ON represents with 1,and OFF represents with 0
#
# - For example case status has two unique labels
#
#    - Denied
#
#    -Certified
#
# - If we apply one hot encoder on case status it will create two extra columns like
#
#     - case_status_Denied
#
#     -case_status_Certified

# %% [markdown]
# |case_status|case_status_Denied|case_Status_Certified|
# |----------|--|--|
# |Denied|1|0|
# |Certified|0|1|

# %% [markdown]
# **Advantages**
#
# - In Machine Learning we have one important property is **Independent of variables**
#
# - Machine Learning models expects variables are **independent each other**
#
# - One hot coder creating new columns,the new columns are **independent each other**
#
# - Independent variables means both variables have **90 degrees phase shift**
#
# - 90 degrees phase shift also called as **perpendicular each other**
#
# - Perpendicular means **orthogonal each other**

# %% [markdown]
# **Disadvantge**
#
# - One hot encoder creates new columns equal to number of unique labels
#
# - If number of unique labels increases,new columns also increase
#
# - The more columns leads data is more
#
# - Then data is more the complexity will increase
#
# - Complexity increases more computation power required
#
# - Also time increase
#
# - The entire process names as **curse of dimensionality**

# %% [markdown]
# **pd.get_dummies**

# %%
df=pd.read_csv(r"C:\Users\hp\OneDrive\Documents\FSDS 7\EDA_PYTHON\Visadataset.csv")

# %%
pd.get_dummies(df['case_status'])
# Out:
#        Certified  Denied
# 0              0       1
# 1              1       0
# 2              0       1
# 3              0       1
# 4              1       0
# ...          ...     ...
# 25475          1       0
# 25476          1       0
# 25477          1       0
# 25478          1       0
# 25479          1       0
#
# [25480 rows x 2 columns]

# %%
df=pd.read_csv(r"C:\Users\hp\OneDrive\Documents\FSDS 7\EDA_PYTHON\Visadataset.csv")

# %%
pd.get_dummies(df)
# Out:
#        no_of_employees  yr_of_estab  prevailing_wage  case_id_EZYV01  \
# 0                14513         2007         592.2029               1
# 1                 2412         2002       83425.6500               0
# 2                44444         2008      122996.8600               0
# 3                   98         1897       83434.0300               0
# 4                 1082         2005      149907.3900               0
# ...                ...          ...              ...             ...
# 25475             2601         2008       77092.5700               0
# 25476             3274         2006      279174.7900               0
# 25477             1121         1910      146298.8500               0
# 25478             1918         1887       86154.7700               0
# 25479             3195         1960       70876.9100               0
#
#        case_id_EZYV02  case_id_EZYV03  case_id_EZYV04  case_id_EZYV05  \
# ...

# %% [markdown]
# **Note**
#
# - Always drop the id column

# %%
df1=pd.read_csv(r"C:\Users\hp\OneDrive\Documents\FSDS 7\EDA_PYTHON\Visadataset.csv")

# %%
df1
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
df1.drop('case_id',inplace=True,axis=1)

# %%
df1
# Out:
#       continent education_of_employee has_job_experience  \
# 0          Asia           High School                  N
# 1          Asia              Master's                  Y
# 2          Asia            Bachelor's                  N
# 3          Asia            Bachelor's                  N
# 4        Africa              Master's                  Y
# ...         ...                   ...                ...
# 25475      Asia            Bachelor's                  Y
# 25476      Asia           High School                  Y
# 25477      Asia              Master's                  Y
# 25478      Asia              Master's                  Y
# 25479      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# ...

# %% [markdown]
# - Generally we will prefer LabelEncoder
#
# - One hot encoder when categorical data has less unique labels
